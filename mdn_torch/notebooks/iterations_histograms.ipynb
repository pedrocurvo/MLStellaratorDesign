# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Datasets

# %%
fname_0 = '../data/1_dataset/first_dataset.csv'
fname_good_0 = '../data/1_dataset/first_good_stels.csv'
print('Reading', fname_0)
df_0 = pd.read_csv(fname_0)
print('Reading', fname_good_0)
df_good_0 = pd.read_csv(fname_good_0)
# Out:
# Reading ../data/1_dataset/first_dataset.csv
# Reading ../data/1_dataset/first_good_stels.csv

# %%
fname_1 = '../data/2_dataset/second_dataset.csv'
fname_good_1 = '../data/2_dataset/second_good_stels.csv'
print('Reading', fname_1)
df_1 = pd.read_csv(fname_1)
print('Reading', fname_good_1)
df_good_1 = pd.read_csv(fname_good_1)
# Out:
# Reading ../data/2_dataset/second_dataset.csv
# Reading ../data/2_dataset/second_good_stels.csv

# %%
fname_2 = '../data/3_dataset/third_dataset.csv'
fname_good_2 = '../data/3_dataset/third_good_stels.csv'
print('Reading', fname_2)
df_2 = pd.read_csv(fname_2)
print('Reading', fname_good_2)
df_good_2 = pd.read_csv(fname_good_2)
# Out:
# Reading ../data/3_dataset/third_dataset.csv
# Reading ../data/3_dataset/third_good_stels.csv

# %%
fname_3 = '../data/4_dataset/fourth_dataset.csv'
fname_good_3 = '../data/4_dataset/fourth_good_stels.csv'
print('Reading', fname_3)
df_3 = pd.read_csv(fname_3)
print('Reading', fname_good_3)
df_good_3 = pd.read_csv(fname_good_3)
# Out:
# Reading ../data/4_dataset/fourth_dataset.csv
# Reading ../data/4_dataset/fourth_good_stels.csv

# %%
fname_4 = '../data/5_dataset/fifth_dataset.csv'
fname_good_4 = '../data/5_dataset/fifth_good_stels.csv'
print('Reading', fname_4)
df_4 = pd.read_csv(fname_4)
print('Reading', fname_good_4)
df_good_4 = pd.read_csv(fname_good_4)
# Out:
# Reading ../data/5_dataset/fifth_dataset.csv
# Reading ../data/5_dataset/fifth_good_stels.csv

# %%
fname_5 = '../data/6_dataset/sixth_dataset.csv'
fname_good_5 = '../data/6_dataset/sixth_good_stels.csv'
print('Reading', fname_5)
df_5 = pd.read_csv(fname_5)
print('Reading', fname_good_5)
df_good_5 = pd.read_csv(fname_good_5)
# Out:
# Reading ../data/6_dataset/sixth_dataset.csv
# Reading ../data/6_dataset/sixth_good_stels.csv

# %% [markdown]
# # Histograms

# %% [markdown]
# ## All Stellarators

# %%
import matplotlib
# Activate the next line to use LaTeX rendering
matplotlib.rcParams['text.usetex'] = True


for col in df_0.columns:
    values_0 = df_0[col].values
    values_good_0 = df_good_0[col].values
    values_1 = df_1[col].values
    values_good_1 = df_good_1[col].values
    values_2 = df_2[col].values
    values_good_2 = df_good_2[col].values
    values_3 = df_3[col].values
    values_good_3 = df_good_3[col].values
    values_4 = df_4[col].values
    values_good_4 = df_good_4[col].values
    values_5 = df_5[col].values
    values_good_5 = df_good_5[col].values
    
    if col in ['nfp']:
        vmin = np.min(values_5) - 0.5
        vmax = np.max(values_5) + 0.5
        num = int(round(vmax - vmin + 1))
    
    else:
        vmin = np.min(values_3)
        vmax = np.max(values_3)
        num = 1001
    
    bins = np.linspace(vmin, vmax, num=num)

    plt.figure(figsize=(10, 6))

    plt.hist(values_0, bins, density=True, alpha=0.5, label='Before training (uniform sampling)', log=True)
    plt.hist(values_1, bins, density=True, alpha=0.5, label='After the first training session', log=True)
    plt.hist(values_2, bins, density=True, alpha=0.5, label='After the second training session', log=True)
    plt.hist(values_3, bins, density=True, alpha=0.5, label='After the third training session', log=True)
    plt.hist(values_4, bins, density=True, alpha=0.5, label='After the fourth training session', log=True)
    plt.hist(values_5, bins, density=True, alpha=0.5, label='After the fifth training session', log=True)

    # plt.title(col)
    plt.xlabel(col, fontsize=20)
    plt.legend(fontsize=12)
    plt.ylabel('Density', fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.tight_layout()
    plt.savefig(f'./images/visual_metrics/histograms/{col}.pdf')
    plt.show()
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 34
#      30 bins = np.linspace(vmin, vmax, num=num)
#      32 plt.figure(figsize=(10, 6))
# ---> 34 plt.hist(values_0, bins, density=True, alpha=0.5, label='Before training (uniform sampling)', log=True)
#      35 plt.hist(values_1, bins, density=True, alpha=0.5, label='After the first training session', log=True)
#      36 plt.hist(values_2, bins, density=True, alpha=0.5, label='After the second training session', log=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/pyplot.py:3354, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3329 @_copy_docstring_and_deprecators(Axes.hist)
#    3330 def hist(
#    3331     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3352     BarContainer | Polygon | list[BarContainer | Polygon],
#    3353 ]:
# -> 3354     return gca().hist(
#    3355         x,
#    3356         bins=bins,
#    3357         range=range,
#    3358         density=density,
#    3359         weights=weights,
#    3360         cumulative=cumulative,
#    3361         bottom=bottom,
#    3362         histtype=histtype,
#    3363         align=align,
#    3364         orientation=orientation,
#    3365         rwidth=rwidth,
#    3366         log=log,
#    3367         color=color,
#    3368         label=label,
#    3369         stacked=stacked,
#    3370         **({"data": data} if data is not None else {}),
#    3371         **kwargs,
#    3372     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/matplotlib/axes/_axes.py:7001, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6997 # Loop through datasets
#    6998 for i in range(nx):
#    6999     # this will automatically overwrite bins,
#    7000     # so that each histogram uses the same bins
# -> 7001     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7002     tops.append(m)
#    7003 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/lib/histograms.py:867, in histogram(a, bins, range, density, weights)
#     865 if weights is None:
#     866     for i in _range(0, len(a), BLOCK):
# --> 867         sa = np.sort(a[i:i+BLOCK])
#     868         cum_n += _search_sorted_inclusive(sa, bin_edges)
#     869 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/fromnumeric.py:1017, in sort(a, axis, kind, order)
#    1015 else:
#    1016     a = asanyarray(a).copy(order="K")
# -> 1017 a.sort(axis=axis, kind=kind, order=order)
#    1018 return a
#
# KeyboardInterrupt:

# %% [markdown]
# ## Good Stellarators

# %%
for col in df_0.columns:
    values_good_0 = df_good_0[col].values
    values_good_1 = df_good_1[col].values
    values_good_2 = df_good_2[col].values
    values_good_3 = df_good_3[col].values
    values_good_4 = df_good_4[col].values
    values_good_5 = df_good_5[col].values
    
    if col in ['nfp']:
        vmin = np.min(values_good_5) - 0.5
        vmax = np.max(values_good_5) + 0.5
        num = int(round(vmax - vmin + 1))
    
    else:
        vmin = np.min(values_good_5)
        vmax = np.max(values_good_5)
        num = 1001
    
    bins = np.linspace(vmin, vmax, num=num)

    plt.hist(values_good_0, bins, density=True, alpha=0.5, label='dataset', log=True)
    plt.hist(values_good_1, bins, density=True, alpha=0.5, label='pred_1', log=True)
    plt.hist(values_good_2, bins, density=True, alpha=0.5, label='pred_2', log=True)
    plt.hist(values_good_3, bins, density=True, alpha=0.5, label='pred_3', log=True)
    plt.hist(values_good_4, bins, density=True, alpha=0.5, label='pred_4', log=True)
    plt.hist(values_good_5, bins, density=True, alpha=0.5, label='pred_5', log=True)

    plt.title(col)
    plt.legend()
    plt.savefig(f'./images/visual_metrics/histograms_good/{col}.pdf')
    plt.show()
    plt.close()
